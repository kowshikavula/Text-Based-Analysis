# %%
# Install wikipedia-api package
# !pip install wikipedia-api

# Install nltk package
# !pip install nltk
# Out:
# Collecting wikipedia-api
#   Obtaining dependency information for wikipedia-api from https://files.pythonhosted.org/packages/2f/3f/919727b460d88c899d110f98d1a0c415264b5d8ad8176f14ce7ad9db0e3b/Wikipedia_API-0.6.0-py3-none-any.whl.metadata
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: requests in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from wikipedia-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from requests->wikipedia-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from requests->wikipedia-api) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from requests->wikipedia-api) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from requests->wikipedia-api) (2023.11.17)
# Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.6.0
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nltk in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import wikipediaapi
import re

# Function to fetch text from Wikipedia API with a custom user agent
def fetch_text_from_wikipedia(title):
    # Custom user agent string
    user_agent = "My Wikipedia Scraper/1.0 (https://example.com/)"
    
    wiki = wikipediaapi.Wikipedia(
        user_agent=user_agent,
        extract_format=wikipediaapi.ExtractFormat.WIKI
    )
    
    page = wiki.page(title)
    if page.exists():
        return page.text
    else:
        return None

# Function to remove stop words using regex
def remove_stopwords(text):
    # Define your list of stop words
    stop_words = ["the", "is", "and", "to", "in", "of", "a", "on", "at", "for", "an"]
    
    # Convert stop words to regex pattern
    stop_words_pattern = r'\b(?:{})\b'.format('|'.join(stop_words))
    
    # Remove stop words using regex
    cleaned_text = re.sub(stop_words_pattern, '', text, flags=re.IGNORECASE)
    return cleaned_text

# Fetching text from Wikipedia for a different page
title = "Artificial intelligence"
text = fetch_text_from_wikipedia(title)

if text:
    # Preprocess text by removing stop words
    cleaned_text = remove_stopwords(text)
    print(cleaned_text[:500])  # Print a portion of the cleaned text
else:
    print(f"Failed to fetch Wikipedia article for '{title}'")
# Out:
# Artificial intelligence (AI)   intelligence  machines or software, as opposed   intelligence  other living beings, primarily  humans. It   field  study  computer science that develops  studies intelligent machines. Such machines may be called AIs.
# AI technology  widely used throughout industry, government,  science. Some high-profile applications are: advanced web search engines (e.g., Google Search), recommendation systems (used by YouTube, Amazon,  Netflix), interacting via human speech (such

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importing Pandas Package.
import pandas as pd
# Storing the Dataset into a File and Reading that Dataset with pandas
file = 'marvel_box_office.csv' #Filepath
df = pd.read_csv(file)
# Printing First 20 Rows of Dataset by Head Method
df.head(20)
# Out:
#                                   Movie Release Date Release Month  \
# 0                              Iron Man     5/2/2008           May
# 1                   The Incredible Hulk    6/13/2008          June
# 2                            Iron Man 2     5/7/2010           May
# 3                                  Thor     5/6/2011           May
# 4    Captain America: The First Avenger    7/22/2011          July
# 5                          The Avengers     5/4/2012           May
# 6                            Iron Man 3     5/3/2013           May
# 7                  Thor: The Dark World    11/8/2013      November
# 8   Captain America: The Winter Soldier     4/4/2014         April
# 9               Guardians of The Galaxy     8/1/2014        August
# 10              Avengers: Age of Ultron     5/1/2015           May
# 11                              Ant-Man    7/17/2015          July
# 12           Captain America: Civil War     5/6/2016           May
# 13                       Doctor Strange    11/4/2016      November
# 14       Guardians of the Galaxy Vol. 2     5/5/2017           May
# 15               Spider-Man: Homecoming     7/7/2017          July
# 16                       Thor: Ragnarok    11/3/2017      November
# 17                        Black Panther    2/16/2018      February
# 18                Avengers Infinity War    4/27/2018         April
# 19                 Ant-Man and the Wasp     7/6/2018          July
#
#     Release Day  Release Year       Ownership  Domestic Box Office  \
# 0             2          2008  Marvel Studios            318604126
# 1            13          2008  Marvel Studios            134806913
# 2             7          2010  Marvel Studios            312433331
# 3             6          2011  Marvel Studios            181030624
# 4            22          2011  Marvel Studios            176654505
# 5             4          2012  Marvel Studios            623357910
# 6             3          2013  Marvel Studios            408992272
# 7             8          2013  Marvel Studios            206362140
# 8             4          2014  Marvel Studios            259746958
# 9             1          2014  Marvel Studios            333714112
# 10            1          2015  Marvel Studios            459005868
# 11           17          2015  Marvel Studios            180202163
# 12            6          2016  Marvel Studios            408084349
# 13            4          2016  Marvel Studios            232641920
# 14            5          2017  Marvel Studios            389813101
# 15            7          2017  Marvel Studios            334201140
# 16            3          2017  Marvel Studios            315058289
# 17           16          2018  Marvel Studios            700059566
# 18           27          2018  Marvel Studios            678815482
# 19            6          2018  Marvel Studios            216648740
#
#     Inflation Adjusted Domestic  International Box Office  \
# 0                     467231126                 266567421
# 1                     197704288                 130766946
# 2                     416973763                 308723058
# 3                     240384926                 268295994
# 4                     234574020                 193915271
# 5                     824617936                 891742301
# 6                     529727993                 806400000
# 7                     267262372                 438240376
# 8                     334777900                 454654931
# 9                     430014621                 437168283
# 10                    573348960                 936311111
# 11                    225092376                 338656286
# 12                    496777822                 743815237
# 13                    283094491                 443701254
# 14                    457606675                 479274862
# 15                    392323076                 544070151
# 16                    369781873                 535424489
# 17                    809179714                 636434754
# 18                    784624259                1369544272
# 19                    250418353                 406495920
#
#     Inflation Adjusted International  ...  Inflation Adjusted Opening Weekend  \
# 0                       3.909196e+08  ...                           149756442
# 1                       1.917794e+08  ...                            81268794
# 2                       4.120220e+08  ...                           170992360
# 3                       3.562619e+08  ...                            87271973
# 4                       2.574941e+08  ...                            86389190
# 5                       1.179654e+09  ...                           274413265
# 6                       1.044452e+09  ...                           225552578
# 7                       5.675710e+08  ...                           111040226
# 8                       5.859873e+08  ...                           122472432
# 9                       5.633228e+08  ...                           121539238
# 10                      1.169556e+09  ...                           238918713
# 11                      4.230191e+08  ...                            71480993
# 12                      9.054768e+08  ...                           218073428
# 13                      5.399258e+08  ...                           103504731
# 14                      5.626270e+08  ...                           171990119
# 15                      6.386910e+08  ...                           137380112
# 16                      6.284243e+08  ...                           144064999
# 17                      7.356375e+08  ...                           233490845
# 18                      1.583019e+09  ...                           297866285
# 19                      4.698575e+08  ...                            87629254
#
#        Budget  Inflation Adjusted Budget  IMDb Score  Meta Score  Tomatometer  \
# 0   186000000                  272767935         7.9          79           94
# 1   137500000                  201653899         6.6          61           67
# 2   170000000                  226882130         6.9          57           72
# 3   150000000                  199180327         7.0          57           77
# 4   140000000                  185901643         6.9          66           80
# 5   225000000                  297644471         8.0          69           91
# 6   200000000                  259040588         7.1          62           79
# 7   150000000                  194267009         6.8          54           67
# 8   170000000                  219106485         7.7          70           90
# 9   170000000                  219057220         8.0          76           92
# 10  365000000                  455925262         7.3          66           76
# 11  130000000                  162384338         7.3          64           83
# 12  250000000                  304335258         7.8          75           90
# 13  165000000                  200783208         7.5          72           89
# 14  200000000                  234782604         7.6          67           85
# 15  175000000                  205434782         7.4          73           92
# 16  180000000                  211264834         7.9          74           93
# 17  200000000                  231174532         7.3          88           96
# 18  300000000                  346761799         8.4          68           85
# 19  130000000                  150263444         7.0          70           87
#
#     Rotten Tomato Audience Score  Run Time In Minutes  Phase  \
# 0                             91                  126    One
# 1                             69                  112    One
# 2                             71                  124    One
# 3                             76                  115    One
# 4                             75                  124    One
# 5                             91                  143    One
# 6                             78                  130    Two
# 7                             75                  112    Two
# 8                             92                  132    Two
# 9                             92                  121    Two
# 10                            82                  141    Two
# 11                            85                  117    Two
# 12                            89                  147  Three
# 13                            86                  115  Three
# 14                            87                  136  Three
# 15                            87                  133  Three
# 16                            87                  130  Three
# 17                            79                  134  Three
# 18                            92                  149  Three
# 19                            80                  118  Three
#
#                  Director
# 0             Jon Favreau
# 1         Louis Leterrier
# 2             Jon Favreau
# 3          Kenneth Brangh
# 4            Joe Johnston
# 5             Joss Whedon
# 6             Shane Black
# 7             Alan Taylor
# 8   Anthony and Joe Russo
# 9              James Gunn
# 10            Joss Whedon
# 11            Peyton Reed
# 12  Anthony and Joe Russo
# 13       Scott Derrickson
# 14             James Gunn
# 15              Jon Watts
# 16          Taika Waititi
# 17           Ryan Coogler
# 18  Anthony and Joe Russo
# 19            Peyton Reed
#
# [20 rows x 23 columns]

# %%
# Data Exploration
# Displaying first few rows
print("First few rows of the dataset:")
print(df.head())
# Out:
# First few rows of the dataset:
#                                 Movie Release Date Release Month  Release Day  \
# 0                            Iron Man     5/2/2008           May            2
# 1                 The Incredible Hulk    6/13/2008          June           13
# 2                          Iron Man 2     5/7/2010           May            7
# 3                                Thor     5/6/2011           May            6
# 4  Captain America: The First Avenger    7/22/2011          July           22
#
#    Release Year       Ownership  Domestic Box Office  \
# 0          2008  Marvel Studios            318604126
# 1          2008  Marvel Studios            134806913
# 2          2010  Marvel Studios            312433331
# 3          2011  Marvel Studios            181030624
# 4          2011  Marvel Studios            176654505
#
#    Inflation Adjusted Domestic  International Box Office  \
# 0                    467231126                 266567421
# 1                    197704288                 130766946
# 2                    416973763                 308723058
# 3                    240384926                 268295994
# 4                    234574020                 193915271
#
#    Inflation Adjusted International  ...  Inflation Adjusted Opening Weekend  \
# 0                      3.909196e+08  ...                           149756442
# 1                      1.917794e+08  ...                            81268794
# 2                      4.120220e+08  ...                           170992360
# 3                      3.562619e+08  ...                            87271973
# 4                      2.574941e+08  ...                            86389190
#
#       Budget  Inflation Adjusted Budget  IMDb Score  Meta Score  Tomatometer  \
# 0  186000000                  272767935         7.9          79           94
# 1  137500000                  201653899         6.6          61           67
# 2  170000000                  226882130         6.9          57           72
# 3  150000000                  199180327         7.0          57           77
# 4  140000000                  185901643         6.9          66           80
#
#    Rotten Tomato Audience Score  Run Time In Minutes  Phase         Director
# 0                            91                  126    One      Jon Favreau
# 1                            69                  112    One  Louis Leterrier
# 2                            71                  124    One      Jon Favreau
# 3                            76                  115    One   Kenneth Brangh
# 4                            75                  124    One     Joe Johnston
#
# [5 rows x 23 columns]

# %%
# Checking data types and missing values
print("\nData types and missing values:")
print(df.info())
# Out:
# Data types and missing values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Movie                               66 non-null     object
#  1   Release Date                        66 non-null     object
#  2   Release Month                       66 non-null     object
#  3   Release Day                         66 non-null     int64
#  4   Release Year                        66 non-null     int64
#  5   Ownership                           66 non-null     object
#  6   Domestic Box Office                 66 non-null     int64
#  7   Inflation Adjusted Domestic         66 non-null     int64
#  8   International Box Office            66 non-null     int64
#  9   Inflation Adjusted International    66 non-null     float64
#  10  Worldwide Box Office                66 non-null     int64
#  11  Inflation Adjusted Worldwide        66 non-null     float64
#  12  Opening Weekend                     66 non-null     int64
#  13  Inflation Adjusted Opening Weekend  66 non-null     int64
#  14  Budget                              66 non-null     int64
#  15  Inflation Adjusted Budget           66 non-null     int64
#  16  IMDb Score                          66 non-null     float64
#  17  Meta Score                          66 non-null     int64
#  18  Tomatometer                         66 non-null     int64
#  19  Rotten Tomato Audience Score        66 non-null     int64
#  20  Run Time In Minutes                 66 non-null     int64
#  21  Phase                               33 non-null     object
#  22  Director                            66 non-null     object
# dtypes: float64(3), int64(14), object(6)
# memory usage: 12.0+ KB
# None

# %%
# Summary statistics
print("\nSummary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#        Release Day  Release Year  Domestic Box Office  \
# count    66.000000     66.000000         6.600000e+01
# mean     10.469697   2013.469697         2.609213e+08
# std       8.304252      6.612854         1.835237e+08
# min       1.000000   1998.000000         8.050977e+06
# 25%       4.000000   2008.000000         1.377073e+08
# 50%       7.500000   2014.500000         2.157992e+08
# 75%      16.000000   2018.750000         3.550611e+08
# max      30.000000   2023.000000         8.583730e+08
#
#        Inflation Adjusted Domestic  International Box Office  \
# count                 6.600000e+01              6.600000e+01
# mean                  3.274682e+08              3.937843e+08
# std                   2.149869e+08              3.322940e+08
# min                   1.180735e+07              2.106557e+06
# 25%                   1.867671e+08              1.789552e+08
# 50%                   2.664460e+08              3.628757e+08
# 75%                   4.389893e+08              5.035717e+08
# max                   9.867541e+08              1.930539e+09
#
#        Inflation Adjusted International  Worldwide Box Office  \
# count                      6.600000e+01          6.600000e+01
# mean                       4.873712e+08          6.547056e+08
# std                        3.853466e+08          5.028107e+08
# min                        3.089421e+06          1.015753e+07
# 25%                        2.176628e+08          3.059375e+08
# 50%                        4.148466e+08          5.996869e+08
# 75%                        6.489334e+08          8.492293e+08
# max                        2.219277e+09          2.788912e+09
#
#        Inflation Adjusted Worldwide  Opening Weekend  \
# count                  6.600000e+01     6.600000e+01
# mean                   8.148394e+08     9.729623e+07
# std                    5.826769e+08     6.674879e+07
# min                    1.489677e+07     4.271451e+06
# 25%                    4.144679e+08     5.517972e+07
# 50%                    7.296717e+08     8.564829e+07
# 75%                    9.969889e+08     1.248166e+08
# max                    3.206031e+09     3.571150e+08
#
#        Inflation Adjusted Opening Weekend        Budget  \
# count                        6.600000e+01  6.600000e+01
# mean                         1.213454e+08  1.617848e+08
# std                          7.664067e+07  7.395979e+07
# min                          6.264398e+06  3.300000e+07
# 25%                          7.243254e+07  1.170000e+08
# 50%                          1.062630e+08  1.625000e+08
# 75%                          1.583527e+08  2.000000e+08
# max                          4.105263e+08  4.000000e+08
#
#        Inflation Adjusted Budget  IMDb Score  Meta Score  Tomatometer  \
# count               6.600000e+01   66.000000   66.000000    66.000000
# mean                2.039654e+08    6.822727   58.696970    66.454545
# std                 8.600754e+07    0.973463   14.631862    25.618612
# min                 5.133008e+07    4.300000   27.000000     9.000000
# 25%                 1.489830e+08    6.300000   48.250000    47.000000
# 50%                 2.017067e+08    6.900000   63.000000    76.500000
# 75%                 2.500000e+08    7.500000   69.000000    88.500000
# max                 4.598253e+08    8.400000   88.000000    96.000000
#
#        Rotten Tomato Audience Score  Run Time In Minutes
# count                     66.000000            66.000000
# mean                      74.196970           123.606061
# std                       18.372404            17.606711
# min                       18.000000            92.000000
# 25%                       64.250000           112.000000
# 50%                       79.500000           124.000000
# 75%                       87.000000           134.000000
# max                       98.000000           181.000000

# %%
# Count plot
plt.figure(figsize=(10, 6))
sns.countplot(x='Ownership', data=df)
plt.title('Movie Ownership Distribution')
plt.xlabel('Ownership')
plt.ylabel('Count of Movies')
plt.show()

# %%
# Box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Ownership', y='Domestic Box Office', data=df)
plt.title('Boxplot of Domestic Box Office by Ownership')
plt.xlabel('Ownership')
plt.ylabel('Domestic Box Office')
plt.show()

# %%
# Importing necessary libraries
# !pip install scikit-learn
import re
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from sklearn.base import BaseEstimator, TransformerMixin

# Define a function to remove stop words using regular expressions
class RemoveStopwords(BaseEstimator, TransformerMixin):
    def __init__(self, stop_words):
        self.stop_words = stop_words

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        clean_text = []
        for text in X:
            clean_text.append(re.sub(r'\b(?:{})\b'.format('|'.join(self.stop_words)), '', text, flags=re.IGNORECASE))
        return clean_text
# Out:
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/f6/28/b569523552a11b49dc4d33952f43dedb23792fe8ce2f2151d070d615861a/scikit_learn-1.4.0-1-cp312-cp312-win_amd64.whl.metadata
#   Downloading scikit_learn-1.4.0-1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.3)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Obtaining dependency information for scipy>=1.6.0 from https://files.pythonhosted.org/packages/f3/31/91a2a3c5eb85d2bfa86d7c98f2df5d77dcdefb3d80ca9f9037ad04393acf/scipy-1.12.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading scipy-1.12.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.3.2)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/b1/2c/f504e55d98418f2fcf756a56877e6d9a45dd5ed28b3d7c267b300e85ad5b/threadpoolctl-3.3.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.3.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.0-1-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.4/10.6 MB 8.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/10.6 MB 11.4 MB/s eta 0:00:01
#    --------- ------------------------------ 2.4/10.6 MB 17.2 MB/s eta 0:00:01
#    --------------- ------------------------ 4.1/10.6 MB 21.6 MB/s eta 0:00:01
#    --------------------- ------------------ 5.7/10.6 MB 24.5 MB/s eta 0:00:01
#    --------------------------- ------------ 7.2/10.6 MB 25.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.8/10.6 MB 28.3 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 28.5 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp312-cp312-win_amd64.whl (45.8 MB)
#    ---------------------------------------- 0.0/45.8 MB ? eta -:--:--
#    - -------------------------------------- 1.3/45.8 MB 28.1 MB/s eta 0:00:02
#    -- ------------------------------------- 3.1/45.8 MB 32.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 4.7/45.8 MB 33.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 6.5/45.8 MB 34.3 MB/s eta 0:00:02
#    ------- -------------------------------- 8.1/45.8 MB 34.6 MB/s eta 0:00:02
#    -------- ------------------------------- 9.7/45.8 MB 34.5 MB/s eta 0:00:02
#    --------- ------------------------------ 11.4/45.8 MB 34.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 13.0/45.8 MB 34.4 MB/s eta 0:00:01
#    ------------ --------------------------- 14.7/45.8 MB 36.4 MB/s eta 0:00:01
#    -------------- ------------------------- 16.3/45.8 MB 32.7 MB/s eta 0:00:01
#    --------------- ------------------------ 18.0/45.8 MB 34.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 19.5/45.8 MB 34.6 MB/s eta 0:00:01
#    ------------------ --------------------- 21.2/45.8 MB 32.8 MB/s eta 0:00:01
#    ------------------- -------------------- 22.9/45.8 MB 36.3 MB/s eta 0:00:01
#    --------------------- ------------------ 24.3/45.8 MB 34.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 26.1/45.8 MB 34.4 MB/s eta 0:00:01
#    ------------------------ --------------- 27.5/45.8 MB 34.4 MB/s eta 0:00:01
#    ------------------------- -------------- 29.2/45.8 MB 34.4 MB/s eta 0:00:01
#    -------------------------- ------------- 30.8/45.8 MB 34.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 32.3/45.8 MB 34.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 33.9/45.8 MB 32.8 MB/s eta 0:00:01
#    ------------------------------ --------- 35.5/45.8 MB 34.4 MB/s eta 0:00:01
#    -------------------------------- ------- 37.1/45.8 MB 34.6 MB/s eta 0:00:01
#    --------------------------------- ------ 38.6/45.8 MB 32.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.3/45.8 MB 34.4 MB/s eta 0:00:01
#    ------------------------------------ --- 41.9/45.8 MB 34.4 MB/s eta 0:00:01
#    ------------------------------------- -- 43.5/45.8 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 36.4 MB/s eta 0:00:01
#    ---------------------------------------  45.8/45.8 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  45.8/45.8 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  45.8/45.8 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------- 45.8/45.8 MB 23.3 MB/s eta 0:00:00
# Downloading threadpoolctl-3.3.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Successfully installed scikit-learn-1.4.0 scipy-1.12.0 threadpoolctl-3.3.0
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Create a function to analyze word frequencies
class WordFrequencyAnalyzer(BaseEstimator, TransformerMixin):
    def __init__(self, max_words=10):
        self.max_words = max_words

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        all_words = ' '.join(X)
        words = re.findall(r'\b\w+\b', all_words.lower())
        word_freq = Counter(words)
        return word_freq.most_common(self.max_words)

# Implement a function to generate word clouds
class WordCloudGenerator(BaseEstimator, TransformerMixin):
    def __init__(self, max_words=100):
        self.max_words = max_words

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        all_words = ' '.join(X)
        wordcloud = WordCloud(width=800, height=400, max_words=self.max_words).generate(all_words)
        return wordcloud

# %%
# Example usage:
# Sample text data
text_data = [
    "The quick brown fox jumps over the lazy dog",
    "Lorem ipsum dolor sit amet, consectetur adipiscing elit",
    "Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium doloremque laudantium",
    "But I must explain to you how all this mistaken idea of denouncing pleasure and praising pain was born",
]

# Create stop words list
stop_words = ['the', 'is', 'and', 'to', 'in', 'of', 'a', 'on', 'at', 'for', 'an', 'but', 'i']

# %%
# Create the pipeline
pipeline = [
    ('remove_stopwords', RemoveStopwords(stop_words)),
    ('word_frequency', WordFrequencyAnalyzer(max_words=10)),
    ('word_cloud', WordCloudGenerator(max_words=100))
]

# Process the text data through the pipeline
processed_data = []
for name, transformer in pipeline:
    processed_data.append(transformer.fit_transform(text_data))

# Display word frequency analysis
print("Word Frequency Analysis:")
for word, freq in processed_data[1]:
    print(f"{word}: {freq}")
# Out:
# Word Frequency Analysis:
# the: 2
# sit: 2
# quick: 1
# brown: 1
# fox: 1
# jumps: 1
# over: 1
# lazy: 1
# dog: 1
# lorem: 1

# %%
# !pip install wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: wordcloud in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (1.26.3)
# Requirement already satisfied: pillow in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Sample text data (replace this with your own text data)
text_data = "Python is a great programming language. It is widely used for data analysis and machine learning."

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud')
plt.show()

# %%
# !pip install textblob
from textblob import TextBlob

# Example text data (replace this with your actual text data)
reviews = [
    "Movie 1 is fantastic! I loved every moment of it.",
    "Movie 2 was disappointing. I expected more from it.",
    "Movie 3 exceeded my expectations. A must-watch!",
    "Movie 4 was okay. Not bad, but not great either.",
    "Movie 5 was terrible. I regret watching it."
]

# Perform sentiment analysis for each review
sentiments = []
for review in reviews:
    analysis = TextBlob(review)
    sentiment_score = analysis.sentiment.polarity
    if sentiment_score > 0:
        sentiment = 'Positive'
    elif sentiment_score < 0:
        sentiment = 'Negative'
    else:
        sentiment = 'Neutral'
    sentiments.append((review, sentiment))

# Display sentiment analysis results
for review, sentiment in sentiments:
    print(f"Review: {review}")
    print(f"Sentiment: {sentiment}")
    print()
# Out:
# Requirement already satisfied: textblob in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.1->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.1->textblob) (4.66.1)
# Requirement already satisfied: colorama in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Review: Movie 1 is fantastic! I loved every moment of it.
# Sentiment: Positive
#
# Review: Movie 2 was disappointing. I expected more from it.
# Sentiment: Negative
#
# Review: Movie 3 exceeded my expectations. A must-watch!
# Sentiment: Neutral
#
# Review: Movie 4 was okay. Not bad, but not great either.
# Sentiment: Positive
#
# Review: Movie 5 was terrible. I regret watching it.
# Sentiment: Negative
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load the Bing Liu Lexicon (Assuming the lexicon is stored in 'bing_liu_lexicon.txt')
bing_liu_lexicon = {}
with open('bing_liu_lexicon.txt', 'r') as file:
    for line in file:
        word, sentiment = line.strip().split('\t')
        bing_liu_lexicon[word] = int(sentiment)

# Example text data
reviews = [
    "Movie 1 is fantastic! I loved every moment of it.",
    "Movie 2 was disappointing. I expected more from it.",
    "Movie 3 exceeded my expectations. A must-watch!",
    "Movie 4 was okay. Not bad, but not great either.",
    "Movie 5 was terrible. I regret watching it."
]

# Perform sentiment analysis for each review
sentiments = []
for review in reviews:
    score = 0
    words = review.lower().split()
    for word in words:
        if word in bing_liu_lexicon:
            score += bing_liu_lexicon[word]
    if score > 0:
        sentiment = 'Positive'
    elif score < 0:
        sentiment = 'Negative'
    else:
        sentiment = 'Neutral'
    sentiments.append((review, sentiment))

# Display sentiment analysis results
for review, sentiment in sentiments:
    print(f"Review: {review}")
    print(f"Sentiment: {sentiment}")
    print()
